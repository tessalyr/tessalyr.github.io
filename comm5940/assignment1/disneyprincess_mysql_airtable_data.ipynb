# %%
# !pip install PyMySQL

# %%
import pymysql.cursors
connection = pymysql.connect(host="localhost", user="root",
passwd="root", db="disneyprincess",
charset='utf8mb4', cursorclass=pymysql.cursors.DictCursor)

# %%
with connection.cursor() as cursor:
        sql = "SELECT * FROM mytable"
        cursor.execute(sql)
        result = cursor.fetchall()
        dataset = []
        temp = {}
        i = 0
        for row in result:
            temp[i] = row
            dataset.append(temp[i])
            i = i + 1
        print('\n')
        print(dataset)
        print('\n')
# Out:
# [{'name': 'Alice', 'chinese_name': '爱丽丝', 'princess_status': 'Unofficial', 'age': None, 'species': 'Human', 'royal_status': 'no', 'nationality': None, 'spouse': None, 'occupation': None, 'animation': 'Alice in Wonderland (1951)', 'original': "Lewis Carroll's children's novel Alice's Adventures in Wonderland", 'first_appearance': '《爱丽丝梦游仙境》Alice in Wonderland (1951)', 'live_action': 'Alice in Wonderland (2010)', 'actress': 'Mia Wasikowska'}, {'name': 'Anna', 'chinese_name': '安娜', 'princess_status': 'Unofficial', 'age': 18, 'species': 'Human', 'royal_status': 'by birth', 'nationality': 'Kingdom of Arendelle', 'spouse': 'Kristoff', 'occupation': 'Princess', 'animation': 'Frozen (2013)', 'original': 'Gerda, a character of "The Snow Queen", a Danish fairytale by Hans Christian Andersen', 'first_appearance': '《冰雪奇缘》Frozen (2013)', 'live_action': None, 'actress': None}, {'name': 'Ariel', 'chinese_name': '爱丽儿', 'princess_status': 'Official', 'age': 16, 'species': 'Mermaid', 'royal_status': '
# ...

# %%
import requests

headers = {
'Authorization': 'Bearer <API Key>',
}

params = (
('view', 'Disney Princess List'),
)

r = requests.get('https://api.airtable.com/v0/appfU4wJMpJkHidFR/Homepage?api_key=keywZFkvBIh6rNMwS&sortField=_createdTime&sortDirection=desc', headers=headers, params=params)
dict = r.json()
dataset = []
name = []
chinese_name = []
princess_status = []
age = []
species = []
royal_status = []
nationality = []
spouse = []
occupation = []
animation = []
original = []
first_appearance = []
live_action = []
actress = []

for i in dict['records']:
     dict = i['fields']
     dataset.append(dict)
print(dataset)
print('\n')
for dicts in dataset:
    name.append(dicts.get('name'))
    chinese_name.append(dicts.get('chinese_name'))
    princess_status.append(dicts.get('princess_status'))
    age.append(dicts.get('age'))
    species.append(dicts.get('species'))
    royal_status.append(dicts.get('royal_status'))
    nationality.append(dicts.get('nationality'))
    spouse.append(dicts.get('spouse'))
    occupation.append(dicts.get('occupation'))
    animation.append(dicts.get('animation'))
    original.append(dicts.get('original'))
    first_appearance.append(dicts.get('first_appearance'))
    live_action.append(dicts.get('live_action'))
    actress.append(dicts.get('actress'))
    
print(name)
# Out:
# [{'name': 'Faline', 'character': [{'id': 'attRjWEzQ5yAWbNsz', 'url': 'https://dl.airtable.com/.attachments/46fb275fe9e7af46bfc9e1750c5c63cf/69557366/Falinecopy.jpg', 'filename': 'Faline copy.jpg', 'size': 23491, 'type': 'image/jpeg', 'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/0d3cda344fd0906ba046c72b1508213e/7c084571', 'width': 48, 'height': 36}, 'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/14972b341b6c8a955c9991a5e81af343/6c659fd7', 'width': 564, 'height': 423}, 'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/a4ff94083f6cff4c25b67728168e8204/0cee0e17', 'width': 3000, 'height': 3000}}}], 'first_appearance': ['reckBosaz8foCm0IH'], 'spouse': 'Bambi', 'chinese_name': '费琳', 'original': " The character of the same name from Felix Salten's Bambi: A Life in the Woods", 'royal_status': 'no', 'key_elements': 'Wildfire, Gives birth to a pair of twin fawns', 'princess_status': 'Unofficial', 'species': 'Deer', 'animation': 'Ba
# ...
